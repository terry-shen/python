# %%
import tensorflow as tf

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据
mnist = input_data.read_data_sets("D:\Tensorflow\Install\MNIST",one_hot=True)

#定义两个变量
batch_size = 80
#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#定义两个placeholder
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

#创建一个简单的神经网络
W = tf.Variable(tf.zeros([784,10]))
B = tf.Variable(tf.zeros([10]))
#prediction = tf.nn.softmax(tf.matmul(x,W)+b)
prediction = tf.nn.softmax(tf.matmul(x,W) + B)

#定义二次代价函数
loss = tf.reduce_mean(tf.square(y-prediction))
train = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

init = tf.global_variables_initializer()

#定义求准确率的方法，结果存放在一个bool型列表中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))#argmax返回一维张量中最大的值所在的位置
#求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))#cast:把bool型转为32位的浮点值

with tf.Session() as sess:
    sess.run(init)
    writer = tf.summary.FileWriter("logs/",sess.graph)
    for epoch in range(201):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train,feed_dict={x:batch_xs,y:batch_ys})
            
        ass = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter " + str(epoch) + ", Testing Accuracy " + str(ass))
# Out:
# Extracting D:\Tensorflow\Install\MNIST\train-images-idx3-ubyte.gz
# Extracting D:\Tensorflow\Install\MNIST\train-labels-idx1-ubyte.gz
# Extracting D:\Tensorflow\Install\MNIST\t10k-images-idx3-ubyte.gz
# Extracting D:\Tensorflow\Install\MNIST\t10k-labels-idx1-ubyte.gz
# Iter 0, Testing Accuracy 0.8475
# Iter 1, Testing Accuracy 0.8769
# Iter 2, Testing Accuracy 0.8865
# Iter 3, Testing Accuracy 0.8939
# Iter 4, Testing Accuracy 0.8976
# Iter 5, Testing Accuracy 0.9016
# Iter 6, Testing Accuracy 0.903
# Iter 7, Testing Accuracy 0.9049
# Iter 8, Testing Accuracy 0.906
# Iter 9, Testing Accuracy 0.9073
# Iter 10, Testing Accuracy 0.9088
# Iter 11, Testing Accuracy 0.9095
# Iter 12, Testing Accuracy 0.9114
# Iter 13, Testing Accuracy 0.9119
# Iter 14, Testing Accuracy 0.9127
# Iter 15, Testing Accuracy 0.9133
# Iter 16, Testing Accuracy 0.9145
# Iter 17, Testing Accuracy 0.9147
# Iter 18, Testing Accuracy 0.9154
# Iter 19, Testing Accuracy 0.9161
# Iter 20, Testing Accuracy 0.9163
# ...
